// %% [markdown]
// # 01 - Print
//
// ## Using ``console.table()``

// %%
console.log('Hello World')

console.log('she said "hello" and then left.')

console.log("she said" + " hello and then left")

console.log("Ethan" + " Lin")
// Out:
// Hello World
// she said "hello" and then left.
// she said hello and then left
// Ethan Lin

// %% [markdown]
// const: For values that will never change (use this by default).let: For values you plan to change later (like a counter in a loop).var: Old, legacy code. Skip learning this entirely.

// %% [markdown]
// # 02 - Input ``prompt()``

// %%
console.log("Hello, my name is: " + prompt("What is your name?:"))

console.log("Hello, you are ", prompt("How old are you?: "), "years old.")
// Out:
// Hello, my name is: Ethan
// Hello, you are  15 years old.

// %% [markdown]
// # 03 - Variable
// **Rules**:
// - Can contain letters``AbCdf``, numbers``12345``, underscores``_``, and dollar sign``$``.
// - Must start with a letter, underscore or dollar sign
// so it CAN NOT start with number.
// - Case Sensitive: ``totalPrice``, ``TotalPrice`` and ``TOTALPRICE`` are entirely different variebles.
// - Cannot be JavaScript keywords: you cannot name a variable after a reserved words like ``const``,``let``,``if``,``while``, or ``function``.
//
// **Best Practice**
// - Use descriptive names: Use ``age`` instead of a.
// - Use camelCase: Unlike Python's ``snake_case``, the absolute standard in JavaScript is to start with a lowercase letter and capitalize the first letter of each added word (e.g., ``totalPrice``, ``isLoggedIn``).
// - Use UPPER_CASE for fixed constants: If a variable is a hardcoded value that will never change throughout the lifetime of the app, use all caps with underscores (e.g., ``const MAX_LOGIN_ATTEMPTS = 5;``).
// - Avoid single-letter names: Except for index counters in loops (like i).
// - Never capital the first letter

// %%
// System reads code from right to left just like python
// prompt("what is your name?: ") = name

// %%
let my_Name = prompt("What is your name?: ")
console.log(my_Name);
// Out:
// Ethan

// %% [markdown]
// # 04 - Keyword Types

// %% [markdown]
// ## ``Const``
// Locks the variable name to its initial value. You cannot reassign it using the equals sign (=).

// %%
const x = 15

console.log(x)
// Out:
// SyntaxError: Identifier 'my_Name' has already been declared

// %% [markdown]
// ### Common Syntax Error

// %%
const my_Name = "Ethan";

myName = "Bob";  //This line does't work because you cannot reassign it when using "const"
// Out:
// SyntaxError: Identifier 'my_Name' has already been declared

// %% [markdown]
// ## ``let``
// What it does: Creates a variable that can be freely reassigned as many times as you want.

// %%
let score = 0;
score += 10

console.log(score)
// Out:
// 10
